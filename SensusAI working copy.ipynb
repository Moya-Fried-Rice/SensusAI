# %%
import pandas as pd

# Read the CSV file (fixed the quotes)
df = pd.read_csv("C:\\Users\\abcjv\\Downloads\\spotify_reviews.csv")

# Display the DataFrame
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
# [84165 rows x 8 columns]

# %%
# Fucntion to convert rating stars to sentiment
def stars_to_sentiment(stars):
    if stars <= 2:
        return 'negative'
    elif stars == 3:
        return 'neutral'
    else:
        return 'positive'

# Ensure 'score' column exists before applying
if 'score' in df.columns:
    df['sentiment'] = df['score'].apply(stars_to_sentiment)
else:
    print("Error: Column 'score' not found in DataFrame.")

df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment
# 0      positive
# 1      positive
# 2      positive
# 3      positive
# 4      negative
# ...         ...
# 84160   neutral
# 84161  positive
# 84162   neutral
# 84163  positive
# 84164  negative
#
# [84165 rows x 9 columns]

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import contractions

def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    return ' '.join(filtered_tokens)

df['processed_content'] = df['content'].apply(preprocess_text)
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment                                  processed_content
# 0      positive                                               good
# 1      positive  love app much using spotify 2 years different ...
# 2      positive                                            perfect
# 3      positive  best around music streaming app used family pl...
# 4      negative                   fr gatekeeping play button songs
# ...         ...                                                ...
# 84160   neutral  decent music streaming app around right kinks ...
# 84161  positive  premium user years spotify fantastic service u...
# 84162   neutral  lot ads sudden even watch video want uninterru...
# 84163  positive  ui could better think search bar times liked s...
# 84164  negative  good till could listen music wanted set playli...
#
# [84165 rows x 10 columns]

# %%
from sklearn.utils import resample
import random

# Identify the maximum class size
max_class_size = df['sentiment'].value_counts().max()

# Separate the data by sentiment
negative_samples = df[df['sentiment'] == 'negative'] 
neutral_samples = df[df['sentiment'] == 'neutral']
positive_samples = df[df['sentiment'] == 'positive']

# Slightly oversample all classes 
negative_oversampled = resample(negative_samples, replace=True, n_samples=int(max_class_size * 1.5), random_state=42)
neutral_oversampled = resample(neutral_samples, replace=True, n_samples=int(max_class_size * 1.5), random_state=42)
positive_oversampled = resample(positive_samples, replace=True, n_samples=int(max_class_size * 1.5), random_state=42)

# Combine the oversampled classes to create a more balanced dataset
balanced_df = pd.concat([negative_oversampled, neutral_oversampled, positive_oversampled])

# Shuffle the dataset
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(balanced_df['sentiment'].value_counts())  # Check class balance
# Out:
# sentiment
# positive    73359
# neutral     73359
# negative    73359
# Name: count, dtype: int64

# %%
df_reviews = balanced_df[['content', 'processed_content', 'score', 'sentiment']]

# df_reviews = df['processed_content']

pd.options.display.max_rows = 1000
pd.options.display.width = 1000

df_reviews.head(100)  # Show first 50 rows
df_reviews.tail(100)  # Show last 50 rows
# Out:
#                                                   content                                  processed_content  score sentiment
# 219977  Hate it without premium. They are essentially ...  hate without premium essentially making life e...      1  negative
# 219978  Was great when I started paying years ago. But...  great started paying years ago reason gotten w...      3   neutral
# 219979  Spotify Cares on twitter is easily the best cu...  spotify cares twitter easily best customer ser...      5  positive
# 219980  Can't even play the songs you want, can't list...  ca even play songs want ca listen albums worst...      1  negative
# 219981  Go online to see menu. The Spotify android app...  go online see menu spotify android app many ma...      2  negative
# 219982        Song are good voice but add are very boring                         song good voice add boring      2  negative
# 219983  gives me an ad after every song, even when I g...  gives ad every song even get 30 minutes ad fre...      1  negative
# 219984  I used to love Spotify but suddenly all the ly...  used love spotify suddenly lyrics stopped load...      3   neutral
# 219985  While the extensive choice of music and qualit...  extensive choice music quality sound amazing w...      2  negative
# 219986  I used this app to primarily stream podcasts. ...  used app primarily stream podcasts ads come ti...      1  negative
# 219987  Great for listening to music. I've tried both ...  great listening music tried free version premi...      5  positive
# 219988  You can't do anything without paying for premi...  ca anything without paying premium ca turn shu...      3   neutral
# 219989  I have been using this for a long time. Now st...  using long time starting hate shuffle repeat b...      1  negative
# 219990  It is simply AWESOME... If you can listen to i...  simply awesome listen download listen offline ...      5  positive
# 219991  For the last fifteen years I've never left the...  last fifteen years never left house without he...      5  positive
# 219992  When I search up a song it gives me it but wit...  search song gives ones also ca play songs want...      4  positive
# 219993   Excelente app, of course. I wish it was cheaper.                  excelente app course wish cheaper      4  positive
# 219994                      Spotify tell me to rate them!                                  spotify tell rate      1  negative
# 219995  Generally pretty good. I really wish that they...  generally pretty good really wish would get ra...      4  positive
# 219996  I am disappointed with this new update honestl...  disappointed new update honestly newly downloa...      1  negative
# 219997  No doubt Spotify is the best platform. However...  doubt spotify best platform however app offlin...      3   neutral
# 219998  This is from a premium account experience and ...  premium account experience may apply free vers...      5  positive
# 219999  i got the paid version of this app several yea...  got paid version app several years ago dont us...      4  positive
# 220000  This was a good app but ever since the update ...  good app ever since update ca even listen sing...      2  negative
# 220001  I love Spotify ... until the latest update. I ...  love spotify latest update still like thing an...      4  positive
# 220002  Not bad. Their algorithms are not perfect but ...  bad algorithms perfect decent music streaming ...      4  positive
# 220003     A monthly limit... on lyrics? Wow. Love it! ❤️                      monthly limit lyrics wow love      1  negative
# 220004  Spotify is great overall however for the past ...  spotify great overall however past month judt ...      3   neutral
# 220005  I'm really love the app, but the continued fre...  really love app continued freezing app unable ...      3   neutral
# 220006  Anytime I play a song on Spotify, it would pla...  anytime play song spotify would play another s...      3   neutral
# 220007  Always been great but it keeps crashing. If I ...  always great keeps crashing lock screen music ...      2  negative
# 220008  Keeps shutting off when I go to shut the scree...  keeps shutting go shut screen used fixable swi...      1  negative
# 220009  I love Spotify don't get me wrong, but it does...  love spotify get wrong play songs example list...      3   neutral
# 220010  I'm a new user who is still on a premium trial...  new user still premium trial already signed pr...      4  positive
# 220011  Honestly Spotify was on of the best apps I use...  honestly spotify best apps used listening musi...      3   neutral
# 220012  I loved this app before the update... When the...  loved app update option pick one u wan na list...      3   neutral
# 220013  I cant even have this app on my phone it is cr...  cant even app phone crashing system ui phone e...      1  negative
# 220014  I love it, I have preiemim, only thing it ther...  love preiemim thing lot songs ca complain k re...      4  positive
# 220015  Spotify is super dope. I love how everyday the...  spotify super dope love everyday new mixes dif...      5  positive
# 220016  This app us getting worse day by day. Everythi...  app us getting worse day day everything requir...      5  positive
# 220017  There's a problem I get where I can't add song...  problem get ca add songs playlist cause app fr...      4  positive
# 220018  It used to be great, but recently it just spam...  used great recently spams homepage podcasts op...      2  negative
# 220019  I've tried literally everything I could find a...  tried literally everything could find reason l...      3   neutral
# 220020  Experience on Bluetooth is unstable at times (...  experience bluetooth unstable times stops play...      3   neutral
# 220021  Good when you pay but stupid when you don't. 5...  good pay stupid 5 ads 1 song absolutely sad be...      4  positive
# 220022  "Watch an ad for 30 minutes of ad free listeni...  watch ad 30 minutes ad free listening gives on...      1  negative
# 220023  App constantly says I'm offline when I am not,...  app constantly says offline stops playing scre...      1  negative
# 220024  Worst experience.. Free version is unusable !!...  worst experience free version unusable u skip ...      1  negative
# 220025  Recently the app has been plagued with bugs - ...  recently app plagued bugs common experience lo...      1  negative
# 220026  Lately my Spotify playlists have been acting u...  lately spotify playlists acting went playlist ...      3   neutral
# 220027  I've just switched to Spotify and it won't pla...  switched spotify wo play anything long app see...      1  negative
# 220028  Extreme lack of freedom, Spotify kindly throws...  extreme lack freedom spotify kindly throws sug...      1  negative
# 220029  Have encountered a problem lately where my Spo...  encountered problem lately spotify keeps stopp...      2  negative
# 220030  Please fix whatever hot mess you have made of ...  please fix whatever hot mess made android app ...      1  negative
# 220031  It's a good app, better than YouTube when it c...  good app better youtube comes music however ly...      3   neutral
# 220032  Spotify is my go to music streaming platform. ...  spotify go music streaming platform easy creat...      4  positive
# 220033  Usually works well but currently there are so ...  usually works well currently horrible glitches...      3   neutral
# 220034  It's pretty good, but a bit buggy at times. Re...  pretty good bit buggy times really annoying ad...      3   neutral
# 220035  Almost every time I bring the app up after swi...  almost every time bring app switching differen...      1  negative
# 220036  Pretty solid. Needs better search engine thoug...  pretty solid needs better search engine though...      4  positive
# 220037  I hv been using this app without any problems,...  hv using app without problems sure since app s...      3   neutral
# 220038  The free Spotify experience is awful. Never us...  free spotify experience awful never using app ...      1  negative
# 220039  Everytime i want to listen to music while doin...  everytime want listen music something else pho...      3   neutral
# 220040  Good selection, and overall good. However ther...  good selection overall good however way downlo...      4  positive
# 220041  I was just happened before in the past when si...  happened past sitting someone device rather ni...      3   neutral
# 220042  Great app in general, it has many varieties of...  great app general many varieties music many gr...      3   neutral
# 220043  Switching to Spotify premium is the best decis...  switching spotify premium best decision ever e...      5  positive
# 220044  Vast library of quality music to enjoy, but ev...  vast library quality music enjoy ever since go...      3   neutral
# 220045  I'm finding it easy enough to use, and celebra...  finding easy enough use celebrate extensive co...      5  positive
# 220046  I can never think of any other app other than ...  never think app spotify ui unique smooth sound...      5  positive
# 220047  I love Spotify, but their app is so broken it'...  love spotify app broken unreal nasty habit say...      3   neutral
# 220048  I like Spotify very much,it have all music all...  like spotify much music allover around world o...      5  positive
# 220049  The playlists put together by Spotify introduc...  playlists put together spotify introduces many...      5  positive
# 220050  This app experience is all focused on online e...  app experience focused online experience playl...      3   neutral
# 220051  I have had Spotify for over two years at this ...  spotify two years point though recently absolu...      2  negative
# 220052  I love this app! I like that it even has stati...  love app like even stations languages options ...      4  positive
# 220053  The playback screen freezes constantly, especi...  playback screen freezes constantly especially ...      2  negative
# 220054  It's an amazing app but the only wpeblem is wh...  amazing app wpeblem go liked music also gives ...      4  positive
# 220055  ngl this is good but bruh it adds unwanted son...  ngl good bruh adds unwanted songs playlist sel...      2  negative
# 220056  Congrats Spotify. Now it seems that Spotify wi...  congrats spotify seems spotify ruined keeps pa...      1  negative
# 220057  It's a pretty good music app, but what I absol...  pretty good music app absolutely hate unpaid v...      2  negative
# 220058  This is a terrible music app if you don't buy ...  terrible music app buy premium ca even choose ...      1  negative
# 220059  The worst online support regarding to subscrip...  worst online support regarding subscriptions c...      1  negative
# 220060  Only used it for a few hours before forced to ...  used hours forced uninstall like app ca stoppe...      1  negative
# 220061  Great interface with other apps!! Love you guy...  great interface apps love guys great sound def...      5  positive
# 220062  The app experience is much better than other s...  app experience much better services one thing ...      4  positive
# 220063  Spotify is amazing but theres one problem, for...  spotify amazing theres one problem reason keep...      3   neutral
# 220064  I do like it, but what is with the shuffle fea...  like shuffle feature pay premium hit shuffle s...      3   neutral
# 220065  i don't know what happened with the recent upd...  know happened recent update add profile option...      3   neutral
# 220066  Its perfect for just about everything. The ads...  perfect everything ads suck repetitive give 30...      5  positive
# 220067  No wonder why so many people use it. You pick ...  wonder many people use pick artists like save ...      5  positive
# 220068  what is this fam like i just wish that there w...  fam like wish less ads like getting 6 ads 3 so...      3   neutral
# 220069  Bring back the Widget!! I have no idea why the...  bring back widget idea removed first place peo...      1  negative
# 220070  I have been using spotify for many years now a...  using spotify many years love one thing think ...      4  positive
# 220071  I love the app! But why only 3 stars? Well it ...  love app 3 stars well started really nicely th...      3   neutral
# 220072  I do love this app. Don't get me wrong. It has...  love app get wrong large library songs lot son...      3   neutral
# 220073  On a daily basis Spotify tells me that I am no...  daily basis spotify tells connected internet t...      3   neutral
# 220074  Every time I connect to the Bluetooth in my ca...  every time connect bluetooth car another bluet...      3   neutral
# 220075  My only complaint is that shuffle play doesn't...  complaint shuffle play actually shuffle stream...      4  positive
# 220076  Without premium, you're basically listening to...  without premium basically listening ads song b...      3   neutral

# %%
from matplotlib import pyplot as plt
import numpy as np

# Count the number of occurrences for each sentiment category
sentiment_count = df_reviews['sentiment'].value_counts()

plt.figure(figsize=(8, 8))  # Set the figure size

# Create a pie chart to visualize sentiment distribution
plt.pie(sentiment_count, labels=sentiment_count.index, autopct="%1.1f%%", startangle=140)

plt.title('Sentiment Distribution')  # Add a title to the chart
plt.axis('equal')  # Ensure the pie chart is displayed as a circle
plt.show()  # Display the plot

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(df_reviews['processed_content'], df_reviews['sentiment'], test_size=0.2, random_state=42)

# Initialize TF-IDF Vectorizer with bigrams, minimum document frequency of 3, and max document frequency of 90%
vectorizer = TfidfVectorizer(ngram_range=(1, 2), min_df=3, max_df=0.9, sublinear_tf=True)

# Fit the vectorizer on training data and transform it into numerical feature vectors
X_train_vectorized = vectorizer.fit_transform(X_train)

# Transform the test data using the fitted vectorizer
X_test_vectorized = vectorizer.transform(X_test)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.metrics import confusion_matrix

# def plot_confusion_matrix(cm, classes, normalized=True, cmap='BuPu'):
#     plt.figure(figsize=[10, 8])
    
#     if normalized:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize by row sum
    
#     sns.heatmap(cm, annot=True, fmt='.2f' if normalized else 'g', 
#                 xticklabels=classes, yticklabels=classes, cmap=cmap)
    
#     plt.xlabel('Predicted Label')
#     plt.ylabel('True Label')
#     plt.title('Confusion Matrix')
#     plt.show()

# # Compute confusion matrix
# cm = confusion_matrix(y_test, preds)

# # Call the function with correct labels
# plot_confusion_matrix(cm, ['negative', 'neutral', 'positive'])

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_vectorized, y_train)

# %%
from sklearn.metrics import classification_report

# from sklearn.naive_bayes import MultinomialNB
# nb = MultinomialNB()
# nb.fit(X_train_vectorized, y_train)
# preds = nb.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier(n_estimators=100, random_state=42)
# rf.fit(X_train_vectorized, y_train)
# preds = rf.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_smote, y_train_smote)
preds = rf.predict(X_test_vectorized)
print(classification_report(y_test, preds))

# from sklearn.linear_model import LogisticRegression
# lr = LogisticRegression(solver='liblinear')
# lr.fit(X_train_vectorized, y_train)
# preds = lr.predict(X_test_vectorized)
# print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.97      0.98      0.98     14691
#      neutral       1.00      0.99      1.00     14577
#     positive       0.98      0.97      0.98     14748
#
#     accuracy                           0.98     44016
#    macro avg       0.98      0.98      0.98     44016
# weighted avg       0.98      0.98      0.98     44016

# %%
def predict_sentiment(review):
    processed_review = preprocess_text(review)
    vectorized_review = vectorizer.transform([processed_review])
    sentiment = rf.predict(vectorized_review)[0]
    return sentiment

# %%
new_review = """

It's pretty good!! 

"""
print("Predicted sentiment:", predict_sentiment(new_review))
# Out:
# Predicted sentiment: positive
