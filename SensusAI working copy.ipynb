# %%
import pandas as pd

# Read the CSV file (fixed the quotes)
df = pd.read_csv("C:\\Users\\abcjv\\Downloads\\spotify_reviews.csv")

# Display the DataFrame
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
# [84165 rows x 8 columns]

# %%
# Fucntion to convert rating stars to sentiment
def stars_to_sentiment(stars):
    if stars <= 2:
        return 'negative'
    elif stars == 3:
        return 'neutral'
    else:
        return 'positive'

# Ensure 'score' column exists before applying
if 'score' in df.columns:
    df['sentiment'] = df['score'].apply(stars_to_sentiment)
else:
    print("Error: Column 'score' not found in DataFrame.")

df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment
# 0      positive
# 1      positive
# 2      positive
# 3      positive
# 4      negative
# ...         ...
# 84160   neutral
# 84161  positive
# 84162   neutral
# 84163  positive
# 84164  negative
#
# [84165 rows x 9 columns]

# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import contractions

# Contraction words
contractions = {
    "isn't": "is not", "aren't": "are not", "can't": "cannot", "couldn't": "could not",
    "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not",
    "hasn't": "has not", "haven't": "have not", "hadn't": "had not", "isn't": "is not",
    "it's": "it is", "let's": "let us", "ma'am": "madam", "mightn't": "might not",
    "mustn't": "must not", "needn't": "need not", "needn't": "need not", "shan't": "shall not",
    "she'd": "she would", "she'll": "she will", "she's": "she is", "shouldn't": "should not",
    "that's": "that is", "there's": "there is", "they'd": "they would", "they'll": "they will",
    "they're": "they are", "they've": "they have", "wasn't": "was not", "weren't": "were not",
    "what's": "what is", "what'll": "what will", "what're": "what are", "what've": "what have",
    "where's": "where is", "where've": "where have", "who's": "who is", "who'll": "who will",
    "who're": "who are", "who've": "who have", "why's": "why is", "why're": "why are",
    "why've": "why have", "won't": "will not", "wouldn't": "would not", "you'd": "you would",
    "you'll": "you will", "you're": "you are", "you've": "you have"
}

# Important words
sentiment_important_words = {
    "not", "no", "very", "good", "bad", "excellent", "love", "hate", "great", "feel", "wish", "would", "should"
}

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to NOUN if unknown
    
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Expand contractions (assumes contractions dictionary is available)
    for contraction, expansion in contractions.items():
        text = text.replace(contraction, expansion)

    # Remove punctuation using regular expressions
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Initialize the lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Define English stopwords
    stop_words = set(stopwords.words('english'))

    # Customize the stopwords list for sentiment analysis (add negations or important words)
    stop_words = stop_words - sentiment_important_words  # Remove sentiment important words from stopwords

    # POS tagging
    pos_tags = pos_tag(tokens)

    # Apply lemmatization based on POS tags and filter out stopwords and single-letter words
    lemmatized_tokens = [
        lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags
        if word.isalnum() and word not in stop_words and len(word) > 1  # Filter single-letter words
    ]

    # Join the lemmatized tokens back into a single string
    return ' '.join(lemmatized_tokens)

df['processed_content'] = df['content'].apply(preprocess_text)
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment                                  processed_content
# 0      positive                                               good
# 1      positive  love app much ive use spotify year different a...
# 2      positive                                            perfect
# 3      positive  best around music stream app use family plan g...
# 4      negative               yall fr gatekeeping play button song
# ...         ...                                                ...
# 84160   neutral  decent music stream app around right kink ridi...
# 84161  positive  premium user year spotify fantastic service us...
# 84162   neutral  lot ad sudden even watch video want uninterrup...
# 84163  positive  ui could good think should search bar time lik...
# 84164  negative  good till could not listen music want set play...
#
# [84165 rows x 10 columns]

# %%
from sklearn.utils import resample
from concurrent.futures import ThreadPoolExecutor
import random
from nltk.corpus import wordnet

def get_synonym(word):
    """
    Returns a synonym for the given word that is different from the original word.
    If no synonym is found, returns the original word.
    """
    word_lower = word.lower()
    
    try:
        synsets = wordnet.synsets(word)
        for synset in synsets:
            for lemma in synset.lemmas():
                lemma_name = lemma.name().lower()
                if lemma_name != word_lower:  # Ensure the synonym is different
                    return lemma.name().replace("_", " ")  # Replace underscores with spaces
    except Exception as e:
        print(f"Error processing word '{word}': {e}")
    
    return word  # Return original if no different synonym is found

# Function to replace at least 60% of words in a sentence with synonyms
def replace_random_words(sentence):
    """
    Replaces at least 60% of words in the sentence with their synonyms.
    """
    words = sentence.split()
    if not words:
        return sentence

    num_words_to_replace = max(1, int(len(words) * 0.6))  # At least 60% of words
    replace_indices = random.sample(range(len(words)), min(num_words_to_replace, len(words)))

    for index in replace_indices:
        words[index] = get_synonym(words[index].lower())  # Convert to lowercase for matching

    return ' '.join(words)

# Function to oversample and augment the data
def oversample_and_augment(sentiment_class, target_size, sentiment_name):
    oversampled = resample(sentiment_class, replace=True, n_samples=target_size, random_state=42)
    oversampled['processed_content'] = oversampled['processed_content'].apply(replace_random_words)
    return oversampled

# Assuming 'df' is your original DataFrame
# Separate the data by sentiment
negative_samples = df[df['sentiment'] == 'negative']
neutral_samples = df[df['sentiment'] == 'neutral']
positive_samples = df[df['sentiment'] == 'positive']

# The target size for neutral and positive classes will be 1.5 times the size of the negative class
target_size_neutral_positive = int(len(negative_samples) * 2)
target_size_negative = target_size_neutral_positive  # Also oversample negative class to match

# Create a thread pool to process the classes in parallel
with ThreadPoolExecutor() as executor:
    futures = []
    futures.append(executor.submit(oversample_and_augment, negative_samples, target_size_negative, 'Negative'))
    futures.append(executor.submit(oversample_and_augment, neutral_samples, target_size_neutral_positive, 'Neutral'))
    futures.append(executor.submit(oversample_and_augment, positive_samples, target_size_neutral_positive, 'Positive'))

    # Collect the results
    negative_oversampled = futures[0].result()
    neutral_oversampled = futures[1].result()
    positive_oversampled = futures[2].result()

# Combine the oversampled data
balanced_df = pd.concat([negative_oversampled, neutral_oversampled, positive_oversampled])

# Shuffle the dataset
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(balanced_df['sentiment'].value_counts())  # Check class balance
# Out:
# c:\Users\abcjv\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\corpus\reader\wordnet.py:1580: UserWarning: No WordNet synset found for pos=n at offset=10480730.
#   warnings.warn(f"No WordNet synset found for pos={pos} at offset={offset}.")
# Error processing word 'prof': 'NoneType' object has no attribute 'lemmas'
# Error processing word 'sniping': line '01135683 33 v 01 snipe 1 002 @ 01143838 v 0000 + 02031934 n 0101 01 + 02  1 This software and database is being provided to you, the LICENSEE, by  \n': not enough values to unpack (expected 2, got 1)
# sentiment
# negative    97812
# positive    97812
# neutral     97812
# Name: count, dtype: int64

# %%
df_reviews = balanced_df[['content', 'processed_content', 'score', 'sentiment']]

# df_reviews = df['processed_content']

pd.options.display.max_rows = 1000
pd.options.display.width = 1000

df_reviews.head(100)  # Show first 50 rows
df_reviews.tail(100)  # Show last 50 rows
# Out:
#                                                   content                                  processed_content  score sentiment
# 293336  Spotify is the best app ever! It made me thank...  spotify best app of all time brand thankful li...      5  positive
# 293337  Never failed me. Great song selection with a w...  ne'er fail great song choice wide variety euph...      5  positive
# 293338  This app is okay, but it just sucks. I don't g...  app okay sucking non acquire unlike desktop ve...      3   neutral
# 293339  If some of the big fixes actually worked then ...  big hole actually piece of work evaluation wou...      3   neutral
# 293340                Great selection of music on Spotify                   outstanding choice music spotify      5  positive
# 293341  The quality of life has gone down drastically....  caliber life spell drastically many rag thing ...      3   neutral
# 293342  Don't get me wrong good app But when I make a ...  non acquire wrong good app brand playlist mayb...      2  negative
# 293343  I've rejoined this app after some years of abs...  ive rejoin app twelvemonth remove really the l...      3   neutral
# 293344  A great app to listen to music on, irritating ...  outstanding app hear music annoy piece of work...      2  negative
# 293345  Spotify hates podcasts The new episodes list d...  spotify hatred podcast new installment list no...      1  negative
# 293346  I have spotify premium and I like making my pl...  spotify insurance premium like brand playlist ...      3   neutral
# 293347  I usually really like this app. But as of the ...  usually truly the like app stopping point mont...      3   neutral
# 293348  There are problems with my account, for exampl...  problem history illustration storehouse should...      3   neutral
# 293349  I love using the app for music, but I'll remov...  passion use app euphony ill remove vocal play ...      3   neutral
# 293350  I love the app but honestly the song reccomend...  love app honestly vocal reccomendation start u...      3   neutral
# 293351  Man, I'm giving it a 3 cause this app is getti...  man im spring reason app get roadster hell att...      3   neutral
# 293352  The recent update is good 😊👍. But the lyrics c...                Holocene update good words not load      4  positive
# 293353  Unable to login using mobile number. Entered c...  unable login usage mobile number come in right...      1  negative
# 293354  could've been 5. first of all there's too much...  couldve first a lot advertisement get advertis...      2  negative
# 293355  "TikTok UI" has ceased for the moment and norm...  tiktok ui discontinue moment convention euphon...      4  positive
# 293356  Love the app. I love how I can have music play...  love app love music acting television usage la...      4  positive
# 293357  It really needs a 2.5 0 to 2.75 rating. Spotif...  really demand twenty-five 275 evaluation spoti...      3   neutral
# 293358  Spotify is pretty ok, but Spotify Premium is t...  spotify pretty Oklahoma spotify premium ace ap...      5  positive
# 293359  Hate it without premium. They are essentially ...  hatred without insurance premium basically mak...      1  negative
# 293360  Spotify: Ads and premium app...⚠️Alert⚠️,see d...  spotify ad insurance premium appalertsee data ...      1  negative
# 293361  Can't even play the songs you want, can't list...  not evening play song privation not hear album...      1  negative
# 293362  Go online to see menu. The Spotify android app...  spell on-line see bill of fare spotify android...      2  negative
# 293363  I have no idea why this application has anythi...  nobelium thought application anything ace nobe...      5  positive
# 293364        Song are good voice but add are very boring       song goodness vocalization add very drilling      2  negative
# 293365  Wow! to be honest this is my first time ever g...  belly laugh honest number one time of all time...      5  positive
# 293366  Getting freedom to listen to music that I can ...      get exemption listen euphony connect astonish      5  positive
# 293367  While the extensive choice of music and qualit...  extended pick music caliber auditory sensation...      2  negative
# 293368  I used this app to primarily stream podcasts. ...  usage app primarily watercourse podcast ad sem...      1  negative
# 293369  As much as i love spotify, im hoping we can no...  a lot passion spotify im hops normalize make p...      3   neutral
# 293370  I've been using Spotify for many years as my p...  ive use spotify many twelvemonth primary music...      5  positive
# 293371  I have been using this for a long time. Now st...  use hanker clip start hate itthe shuffling rep...      1  negative
# 293372  I have no idea why this application has anythi...  nobelium thought practical application anythin...      5  positive
# 293373  Sometimes I don't know what song to pick, but ...  sometimes non cognize vocal pick want euphony ...      5  positive
# 293374  I've learned it's easier on a laptop, the app ...  ive larn easy laptop computer app really hard ...      4  positive
# 293375  Been a big fan of Spotify ever since I first g...  big sports fan spotify of all time since numbe...      3   neutral
# 293376  I can listen to the songs with or without my d...  listen song without device whistle sofago szas...      5  positive
# 293377  Great app. It has so many songs. You can also ...  outstanding app many song besides make very pl...      5  positive
# 293378  If you are a music fan, you need this app. Yes...  music fan need app yes free people variant pro...      5  positive
# 293379  Spotify is an amazing app if you like listenin...  spotify amaze app like hear euphony make custo...      5  positive
# 293380  What have you done to it in the latest update ...  do belated update twenty-four hours ago play 1...      1  negative
# 293381  Spotify is a really lovely, and well thought o...  spotify truly lovely wellspring idea app altho...      3   neutral
# 293382  Nice music all songs of my Playlist are there ...  nice music vocal playlist available large job ...      4  positive
# 293383                                     Nice music app                                     nice music app      4  positive
# 293384  Keeps shutting off when I go to shut the scree...  keep close go close silver screen use fixable ...      1  negative
# 293385  UX work needed... By animation it looks I can ...  ux piece of work need life look pilfer opened ...      3   neutral
# 293386  I like Spotify overall, BUT: I don't know whos...  the like spotify boilersuit non know whose bri...      4  positive
# 293387  I enjoy it mainly cause i can create my own st...  bask chiefly reason make place hear vocal priv...      3   neutral
# 293388  I love everything about this app honestly....B...  passion everything app honestlybeen usage twel...      5  positive
# 293389  I cant even have this app on my phone it is cr...  buzzword even app telephone clang system ui no...      1  negative
# 293390  This app is really great,I use this a lot. I w...  app really greati usage batch would passion pu...      4  positive
# 293391  This app is my go to for everything music and ...  app spell everything euphony podcast normally ...      3   neutral
# 293392  Just absolutely amazing!! Simple to use with a...  perfectly amaze simpleton use mindblowing asso...      5  positive
# 293393  Too many ads and can't skip to different songs...  many ad non skip different vocal want yes cogn...      4  positive
# 293394  Quality of the music is always great, Premium ...  quality euphony ever outstanding premium actua...      5  positive
# 293395  Best music app. Period. Best music quality and...  best music app period topper music caliber sou...      5  positive
# 293396  Don't get me wrong, the features of this app a...  not get wrongfulness feature app amaze evening...      3   neutral
# 293397  Pay 2 win, Totally worth it. Have been using i...  wage winnings wholly Charles Frederick Worth u...      5  positive
# 293398  "Watch an ad for 30 minutes of ad free listeni...  ticker advertisement thirty min ad free people...      1  negative
# 293399  App constantly says I'm offline when I am not,...  app constantly state im offline non halt drama...      1  negative
# 293400                         Best update since Pandora.                        topper update since pandora      5  positive
# 293401  I've just switched to Spotify and it won't pla...  ive electric switch spotify not drama anything...      1  negative
# 293402  Please fix whatever hot mess you have made of ...  delight hole whatever hot messiness brand huma...      1  negative
# 293403  Oh my goddd this is so annoying. The app itsel...  Ohio goddd rag app mulct except keep halt the ...      2  negative
# 293404  The homepage widget of Spotify has not been wo...  homepage doodad spotify not piece of work long...      3   neutral
# 293405  Almost every time I bring the app up after swi...  about every time bring app switch unlike app s...      1  negative
# 293406  Spotify connect connection to wireless speaker...  spotify connect connection radio talker awful ...      3   neutral
# 293407  The free Spotify experience is awful. Never us...  free people spotify see awful ne'er usage app ...      1  negative
# 293408  A Good app to listen music for free but the pr...  goodness app hear euphony free job insurance p...      3   neutral
# 293409  Why on earth would you take away the widget???...  world would return outside doodad literally no...      3   neutral
# 293410  I thought about trying to use this app for pod...  believe attempt usage app podcast well euphony...      3   neutral
# 293411            User friendly interface and categories.                 exploiter friendly interface class      5  positive
# 293412  The free version is basically worthless, might...  free people variant basically worthless might ...      3   neutral
# 293413  It's a great streaming service, I switched fro...  great cyclosis service switch virago euphony t...      5  positive
# 293414  I've been using Spotify Premium for ages, and ...  ive usage spotify insurance premium historic p...      5  positive
# 293415  Pretty good, but it's 3 star because of two th...  reasonably good ace 2 matter number one ad lik...      3   neutral
# 293416  This is amazing app . Everything we can listen...  amaze app everything hear freely problem non s...      4  positive
# 293417  good app,I have a suggestion, make it so we ca...  good appi proposition brand hear song without ...      4  positive
# 293418  I really like this app, it gives a good select...  truly the like app spring goodness selection e...      4  positive
# 293419  The recent update sucks. I usually watch and b...  recent update suck normally ticker browsing pl...      3   neutral
# 293420  The best streaming app with creative playlists...  topper streaming app creative play list day-to...      4  positive
# 293421  It's a pretty good music app, but what I absol...  reasonably goodness music app perfectly hatred...      2  negative
# 293422  The worst online support regarding to subscrip...  badness online reinforcement respect subscript...      1  negative
# 293423  Easy to use plus audio controles make it bette...  easygoing usage plus sound controles brand wel...      5  positive
# 293424  Huge song selection, and easy to use UI, but i...  immense vocal choice easy usage ui non pay pre...      3   neutral
# 293425  I like the app in general, but as a non-premiu...  the like app full general nonpremium exploiter...      3   neutral
# 293426  It doesnt tell you what songs you have hidden,...  doesnt tell song hide forget vocal fell accide...      1  negative
# 293427  The app does really poorly when on a bad conne...  app really ailing badness connexion relative a...      3   neutral
# 293428  Bring back the Widget!! I have no idea why the...  bring dorsum doodad no thought remove first to...      1  negative
# 293429  I've got no complain about it until recently t...  ive acquire no kick late though passion could ...      4  positive
# 293430  Please fix the ads problem. everytime when i t...  delight fix advertisement problem everytime be...      3   neutral
# 293431  Pretty good, especially when you have premium,...  reasonably good especially insurance premium j...      3   neutral
# 293432  It's a good app but stop with buy premium on t...  goodness app halt buy premium app annoy omissi...      5  positive
# 293433  I gave Spotify a three-star because today I tr...  spring spotify threestar nowadays attempt list...      3   neutral
# 293434  This app WAS great, it's been weeks since I've...  app outstanding week since ive number non cert...      3   neutral
# 293435  When using it its 100% fine no problems at all...  usage hundred fine nobelium problem problem im...      3   neutral

# %%
from matplotlib import pyplot as plt
import numpy as np

# Count the number of occurrences for each sentiment category
sentiment_count = df_reviews['sentiment'].value_counts()

plt.figure(figsize=(8, 8))  # Set the figure size

# Create a pie chart to visualize sentiment distribution
plt.pie(sentiment_count, labels=sentiment_count.index, autopct="%1.1f%%", startangle=140)

plt.title('Sentiment Distribution')  # Add a title to the chart
plt.axis('equal')  # Ensure the pie chart is displayed as a circle
plt.show()  # Display the plot

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(df_reviews['processed_content'], df_reviews['sentiment'], test_size=0.2, random_state=42)

# Initialize TF-IDF Vectorizer with bigrams, minimum document frequency of 3, and max document frequency of 90%
vectorizer = TfidfVectorizer(ngram_range=(1, 2), min_df=3, max_df=0.9, sublinear_tf=True)

# Fit the vectorizer on training data and transform it into numerical feature vectors
X_train_vectorized = vectorizer.fit_transform(X_train)

# Transform the test data using the fitted vectorizer
X_test_vectorized = vectorizer.transform(X_test)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.metrics import confusion_matrix

# def plot_confusion_matrix(cm, classes, normalized=True, cmap='BuPu'):
#     plt.figure(figsize=[10, 8])
    
#     if normalized:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize by row sum
    
#     sns.heatmap(cm, annot=True, fmt='.2f' if normalized else 'g', 
#                 xticklabels=classes, yticklabels=classes, cmap=cmap)
    
#     plt.xlabel('Predicted Label')
#     plt.ylabel('True Label')
#     plt.title('Confusion Matrix')
#     plt.show()

# # Compute confusion matrix
# cm = confusion_matrix(y_test, preds)

# # Call the function with correct labels
# plot_confusion_matrix(cm, ['negative', 'neutral', 'positive'])

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_vectorized, y_train)

# %%
from sklearn.metrics import classification_report

# from sklearn.naive_bayes import MultinomialNB
# nb = MultinomialNB()
# nb.fit(X_train_vectorized, y_train)
# preds = nb.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier(n_estimators=100, random_state=42)
# rf.fit(X_train_vectorized, y_train)
# preds = rf.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_smote, y_train_smote)
preds = rf.predict(X_test_vectorized)
print(classification_report(y_test, preds))

# from sklearn.linear_model import LogisticRegression
# lr = LogisticRegression(solver='liblinear')
# lr.fit(X_train_vectorized, y_train)
# preds = lr.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

# %%
def predict_sentiment(review):
    processed_review = preprocess_text(review)
    vectorized_review = vectorizer.transform([processed_review])
    sentiment = rf.predict(vectorized_review)[0]
    return sentiment

# %%
new_review = """

I hate it


"""
print("Predicted sentiment:", predict_sentiment(new_review))
# Out:
# Predicted sentiment: positive
