# %%
import pandas as pd

# Read the CSV file (fixed the quotes)
df = pd.read_csv("C:\\Users\\abcjv\\Downloads\\spotify_reviews.csv")

# Display the DataFrame
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
# [84165 rows x 8 columns]

# %%
# Fucntion to convert rating stars to sentiment
def stars_to_sentiment(stars):
    if stars <= 2:
        return 'negative'
    elif stars == 3:
        return 'neutral'
    else:
        return 'positive'

# Ensure 'score' column exists before applying
if 'score' in df.columns:
    df['sentiment'] = df['score'].apply(stars_to_sentiment)
else:
    print("Error: Column 'score' not found in DataFrame.")

df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment
# 0      positive
# 1      positive
# 2      positive
# 3      positive
# 4      negative
# ...         ...
# 84160   neutral
# 84161  positive
# 84162   neutral
# 84163  positive
# 84164  negative
#
# [84165 rows x 9 columns]

# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import contractions

# Contraction words
contractions = {
    "isn't": "is not", "aren't": "are not", "can't": "cannot", "couldn't": "could not",
    "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not",
    "hasn't": "has not", "haven't": "have not", "hadn't": "had not", "isn't": "is not",
    "it's": "it is", "let's": "let us", "ma'am": "madam", "mightn't": "might not",
    "mustn't": "must not", "needn't": "need not", "needn't": "need not", "shan't": "shall not",
    "she'd": "she would", "she'll": "she will", "she's": "she is", "shouldn't": "should not",
    "that's": "that is", "there's": "there is", "they'd": "they would", "they'll": "they will",
    "they're": "they are", "they've": "they have", "wasn't": "was not", "weren't": "were not",
    "what's": "what is", "what'll": "what will", "what're": "what are", "what've": "what have",
    "where's": "where is", "where've": "where have", "who's": "who is", "who'll": "who will",
    "who're": "who are", "who've": "who have", "why's": "why is", "why're": "why are",
    "why've": "why have", "won't": "will not", "wouldn't": "would not", "you'd": "you would",
    "you'll": "you will", "you're": "you are", "you've": "you have"
}

# Important words
sentiment_important_words = {
    "not", "no", "very", "good", "bad", "excellent", "love", "hate", "great", "feel", "wish", "would", "should"
}

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to NOUN if unknown
    
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Expand contractions (assumes contractions dictionary is available)
    for contraction, expansion in contractions.items():
        text = text.replace(contraction, expansion)

    # Remove punctuation using regular expressions
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Initialize the lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Define English stopwords
    stop_words = set(stopwords.words('english'))

    # Customize the stopwords list for sentiment analysis (add negations or important words)
    stop_words = stop_words - sentiment_important_words  # Remove sentiment important words from stopwords

    # POS tagging
    pos_tags = pos_tag(tokens)

    # Apply lemmatization based on POS tags and filter out stopwords and single-letter words
    lemmatized_tokens = [
        lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tags
        if word.isalnum() and word not in stop_words and len(word) > 1  # Filter single-letter words
    ]

    # Join the lemmatized tokens back into a single string
    return ' '.join(lemmatized_tokens)

df['processed_content'] = df['content'].apply(preprocess_text)
df
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...                                                  ...    ...
# 84160  The most decent music streaming app around rig...      3
# 84161  As a premium user for a few years, Spotify is ...      4
# 84162  There is lot of ads all of a sudden, and it's ...      3
# 84163  The UI could be better. I think there should b...      4
# 84164  It was good till I couldn't listen to the musi...      1
#
#        thumbsUpCount reviewCreatedVersion                   at   appVersion  \
# 0                  0                  NaN  2024-05-09 16:28:13          NaN
# 1                  0           8.9.38.494  2024-05-09 16:27:18   8.9.38.494
# 2                  0           8.9.36.616  2024-05-09 16:27:03   8.9.36.616
# 3                  0           8.9.38.494  2024-05-09 16:26:19   8.9.38.494
# 4                  0           8.9.38.494  2024-05-09 16:26:14   8.9.38.494
# ...              ...                  ...                  ...          ...
# 84160              2          8.5.55.1105  2020-04-30 10:02:07  8.5.55.1105
# 84161              0           8.5.27.957  2019-10-11 16:28:13   8.5.27.957
# 84162              0                  NaN  2020-11-27 14:14:34          NaN
# 84163              1           8.5.49.973  2020-03-28 03:50:24   8.5.49.973
# 84164              0          8.5.60.1013  2020-06-13 03:27:52  8.5.60.1013
#
#       sentiment                                  processed_content
# 0      positive                                               good
# 1      positive  love app much ive use spotify year different a...
# 2      positive                                            perfect
# 3      positive  best around music stream app use family plan g...
# 4      negative               yall fr gatekeeping play button song
# ...         ...                                                ...
# 84160   neutral  decent music stream app around right kink ridi...
# 84161  positive  premium user year spotify fantastic service us...
# 84162   neutral  lot ad sudden even watch video want uninterrup...
# 84163  positive  ui could good think should search bar time lik...
# 84164  negative  good till could not listen music want set play...
#
# [84165 rows x 10 columns]

# %%
from sklearn.utils import resample
import random

# Identify the maximum class size
max_class_size = df['sentiment'].value_counts().max()

# Separate the data by sentiment
negative_samples = df[df['sentiment'] == 'negative'] 
neutral_samples = df[df['sentiment'] == 'neutral']
positive_samples = df[df['sentiment'] == 'positive']

# Slightly oversample all classes 
negative_oversampled = resample(negative_samples, replace=True, n_samples=int(max_class_size * 1.7), random_state=42)
neutral_oversampled = resample(neutral_samples, replace=True, n_samples=int(max_class_size * 1.3), random_state=42)
positive_oversampled = resample(positive_samples, replace=True, n_samples=int(max_class_size * 1.7), random_state=42)

# Combine the oversampled classes to create a more balanced dataset
balanced_df = pd.concat([negative_oversampled, neutral_oversampled, positive_oversampled])

# Shuffle the dataset
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(balanced_df['sentiment'].value_counts())  # Check class balance
# Out:
# sentiment
# negative    83140
# positive    83140
# neutral     63577
# Name: count, dtype: int64

# %%
df_reviews = balanced_df[['content', 'processed_content', 'score', 'sentiment']]

# df_reviews = df['processed_content']

pd.options.display.max_rows = 1000
pd.options.display.width = 1000

df_reviews.head(100)  # Show first 50 rows
df_reviews.tail(100)  # Show last 50 rows
# Out:
#                                                   content                                  processed_content  score sentiment
# 229757  gives me an ad after every song, even when I g...  give ad every song even get 30 minute ad free ...      1  negative
# 229758  App is just ok. Can be flaky at times and does...  app ok flaky time not seem good functionality ...      3   neutral
# 229759  While the extensive choice of music and qualit...  extensive choice music quality sound amaze wou...      2  negative
# 229760  I love Spotify it's the best in my opinion. Th...  love spotify best opinion thing make mad somet...      5  positive
# 229761  I used this app to primarily stream podcasts. ...  use app primarily stream podcasts ad come time...      1  negative
# 229762  Spotify changed my life. There's not a single ...  spotify change life not single day not use gre...      5  positive
# 229763  Subject: Request to Bring Back the Lyrics Feat...  subject request bring back lyric feature spoti...      3   neutral
# 229764  Still usefull. I've been using Spotify for 6 y...  still usefull ive use spotify year still find ...      5  positive
# 229765  I have been using this for a long time. Now st...  use long time start hate itthe shuffle repeat ...      1  negative
# 229766  I love this app!!! I use it everyday almost. T...  love app use everyday almost song download fea...      5  positive
# 229767  Awesome music everytime I play a song it just ...       awesome music everytime play song feel right      5  positive
# 229768  I love it. Though I'm getting adds now under p...  love though im get add premium duo plus im not...      4  positive
# 229769  Well it allows me to listen to music offline w...  well allow listen music offline whenever go hi...      5  positive
# 229770                      Spotify tell me to rate them!                                  spotify tell rate      1  negative
# 229771  I use Spotify to listen to music and podcasts,...  use spotify listen music podcasts could please...      4  positive
# 229772  I am disappointed with this new update honestl...  disappoint new update honestly newly download ...      1  negative
# 229773  One star only because I can play music with th...  one star play music phone would not even let p...      1  negative
# 229774  I've been using Spotify for years, I don't fol...  ive use spotify year not follow rate u pop ups...      5  positive
# 229775  the app is very good. I prefer it than any oth...  app very good prefer music stream provider how...      4  positive
# 229776  This was a good app but ever since the update ...  good app ever since update not even listen sin...      2  negative
# 229777  Love this app! An add pops up only after half ...  love app add pop half hour listen music enough...      5  positive
# 229778  Just testing out the Group feature and we have...  test group feature notice issue first connect ...      4  positive
# 229779  Love the app and have been using it for about ...  love app use year yes know long time not reall...      4  positive
# 229780  Finally Zee music are back. I was anyway subsc...  finally zee music back anyway subscribe even y...      5  positive
# 229781     A monthly limit... on lyrics? Wow. Love it! ❤️                       monthly limit lyric wow love      1  negative
# 229782  What have you done to it in the latest update ...  do late update day ago play one song stop pres...      1  negative
# 229783  I don't like the new version, like stop adding...  not like new version like stop add song playli...      3   neutral
# 229784  sometimes it's a bit confusing to figure out h...  sometimes bit confuse figure thing work bother...      3   neutral
# 229785  Always been great but it keeps crashing. If I ...  always great keep crash lock screen music stop...      2  negative
# 229786  Keeps shutting off when I go to shut the scree...  keep shut go shut screen use fixable switch se...      1  negative
# 229787  For years since it came out back in 2015 I've ...  year since come back 2015 ive use spotify very...      3   neutral
# 229788  Spotify is enjoyable and entertaining with fea...  spotify enjoyable entertain feature unexplored...      4  positive
# 229789  Used to be a 5-star app for me, until recently...  use 5star app recently app redownloads playlis...      3   neutral
# 229790  I give Spotify 3 stars for right now. First fo...  give spotify star right first update come mont...      3   neutral
# 229791  I cant even have this app on my phone it is cr...  cant even app phone crash system ui not phone ...      1  negative
# 229792  If u have premium this is the best Music Liste...              premium best music listening platform      5  positive
# 229793  After the most recent update, my Spotify start...  recent update spotify start play music nowhere...      4  positive
# 229794  Sometimes has connection issues with google ho...  sometimes connection issue google home tend ge...      4  positive
# 229795  Changed from SoundCloud really love this app. ...  change soundcloud really love app bit palaver ...      5  positive
# 229796  It used to be great, but recently it just spam...  use great recently spam homepage podcasts no o...      2  negative
# 229797  Only problem I have with Spotify is that , the...  problem spotify way guy change price guy shoul...      3   neutral
# 229798  Having issues when playing music, it randomly ...  issue play music randomly stop also instead he...      3   neutral
# 229799  Cheap subscription for infinite music, on or o...  cheap subscription infinite music offline perf...      5  positive
# 229800  First off when you open your acct it gives you...  first open acct give band choose choose band s...      5  positive
# 229801  "Watch an ad for 30 minutes of ad free listeni...  watch ad 30 minute ad free listen give one son...      1  negative
# 229802  App constantly says I'm offline when I am not,...  app constantly say im offline not stop play sc...      1  negative
# 229803  Worst experience.. Free version is unusable !!...  bad experience free version unusable skip limi...      1  negative
# 229804  Recently the app has been plagued with bugs - ...  recently app plague bug common experience look...      1  negative
# 229805  I've been using this app for years and I alway...  ive use app year always encounter problem rand...      3   neutral
# 229806  I've just switched to Spotify and it won't pla...  ive switch spotify not play anything long app ...      1  negative
# 229807  Extreme lack of freedom, Spotify kindly throws...  extreme lack freedom spotify kindly throw sugg...      1  negative
# 229808  Have encountered a problem lately where my Spo...  encounter problem lately spotify keep stop mid...      2  negative
# 229809  Please fix whatever hot mess you have made of ...  please fix whatever hot mess make android app ...      1  negative
# 229810  I really like Spotify, nice wide song selectio...  really like spotify nice wide song selection s...      3   neutral
# 229811  I love it & the ability to download songs 5/52...  love ability download song 552024my best app ever      5  positive
# 229812  I got this app recently and it worked really w...  get app recently work really well today today ...      3   neutral
# 229813  Can seem to play or view all songs by an artis...  seem play view song artist albums disography s...      3   neutral
# 229814  Almost every time I bring the app up after swi...  almost every time bring app switch different a...      1  negative
# 229815  I was a passionate user of Tidal, that if you ...  passionate user tidal audiophile gadget really...      5  positive
# 229816  Love the app but it needs an update. It's cons...  love app need update constantly stick display ...      3   neutral
# 229817  The free Spotify experience is awful. Never us...  free spotify experience awful never use app no...      1  negative
# 229818  Dope app but spotify wrapped is super buggy th...  dope app spotify wrap super buggy year first t...      3   neutral
# 229819  Love it and I play music all day long. That's ...  love play music day long listen music spotify ...      5  positive
# 229820  the app is fine but when i turn offline mode o...  app fine turn offline mode try listen download...      3   neutral
# 229821  I like spotify, but the problem is that (I don...  like spotify problem dont premium give video a...      3   neutral
# 229822  Great listening experience and a gigantic libr...  great listen experience gigantic library under...      4  positive
# 229823  Would get a better review but the 6 ads after ...  would get good review ad song stupid really an...      3   neutral
# 229824  Please add/edit: -GET RID OF THE HIDDEN SONG f...  please addedit get rid hidden song feature all...      4  positive
# 229825  Used Spotify since it was still in beta (and f...  use spotify since still beta free tehe always ...      5  positive
# 229826  Great app for music. Honestly just rated so th...  great app music honestly rat app would not ask...      5  positive
# 229827  cannot make the app play in the background..(w...  not make app play backgroundwhen clean task ap...      3   neutral
# 229828  Should add a option to block playlist, I've co...  should add option block playlist ive come solu...      4  positive
# 229829  Spotify as a streaming music app simply works....  spotify stream music app simply work late chan...      4  positive
# 229830  Updated review: the app itself is good, but I ...  update review app good major issue shuffle opt...      3   neutral
# 229831  I have had Spotify for over two years at this ...  spotify two year point though recently absolut...      2  negative
# 229832  I love spotify and have the premium subscripti...  love spotify premium subscription think featur...      4  positive
# 229833  The playback screen freezes constantly, especi...  playback screen freeze constantly especially l...      2  negative
# 229834  Offers user friendly interface.....you can hea...  offer user friendly interfaceyou hear favourit...      4  positive
# 229835  ngl this is good but bruh it adds unwanted son...  ngl good bruh add unwanted song playlist self ...      2  negative
# 229836  Congrats Spotify. Now it seems that Spotify wi...  congrats spotify seem spotify ruin keep pay pr...      1  negative
# 229837  It's a pretty good music app, but what I absol...  pretty good music app absolutely hate unpaid v...      2  negative
# 229838  This is a terrible music app if you don't buy ...  terrible music app not buy premium not even ch...      1  negative
# 229839  The worst online support regarding to subscrip...  bad online support regard subscription chat on...      1  negative
# 229840  Only used it for a few hours before forced to ...  use hour force uninstall like app not stop blu...      1  negative
# 229841  Spotify is really good app to listen to music ...  spotify really good app listen music create pl...      4  positive
# 229842  Really solid experience, but the app is pretty...  really solid experience app pretty unusable wi...      5  positive
# 229843  My sentiments are almost 95% spot on with Mr. ...  sentiment almost 95 spot mr larson 073019 new ...      3   neutral
# 229844  I really enjoy the accessibility and sheer lib...  really enjoy accessibility sheer library spoti...      3   neutral
# 229845  I have had spotify for about 4 years now, and ...  spotify year use really like not premium becus...      3   neutral
# 229846  I have nothing but good things to say about Sp...  nothing good thing say spotify great app versa...      5  positive
# 229847  It was great. I don't even find the ads annoyi...  great not even find ad annoy well not time lat...      4  positive
# 229848  I do like the app and music selection but be c...  like app music selection careful downloaded mu...      3   neutral
# 229849  Bring back the Widget!! I have no idea why the...  bring back widget no idea remove first place p...      1  negative
# 229850  Awesome everything I want to listen to Spotify...  awesome everything want listen spotify hasjust...      5  positive
# 229851  Signed up to family premium and haven't looked...  sign family premium not look back fing brillia...      3   neutral
# 229852  Dunno what's wrong but it's always stopped aft...  dunno wrong always stop 23 song play ive try c...      3   neutral
# 229853  The app was good but the adds kept poping ever...  app good add keep pop every three min long one...      3   neutral
# 229854  I've been trying to verify myself as a student...  ive try verify student access student premium ...      3   neutral
# 229855     The music I love to hear! What else can I say!                           music love hear else say      5  positive
# 229856  Hey! Had this app for about a year now, and I ...  hey app year never issue spotify ever since ne...      3   neutral

# %%
from matplotlib import pyplot as plt
import numpy as np

# Count the number of occurrences for each sentiment category
sentiment_count = df_reviews['sentiment'].value_counts()

plt.figure(figsize=(8, 8))  # Set the figure size

# Create a pie chart to visualize sentiment distribution
plt.pie(sentiment_count, labels=sentiment_count.index, autopct="%1.1f%%", startangle=140)

plt.title('Sentiment Distribution')  # Add a title to the chart
plt.axis('equal')  # Ensure the pie chart is displayed as a circle
plt.show()  # Display the plot

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Split the dataset into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(df_reviews['processed_content'], df_reviews['sentiment'], test_size=0.2, random_state=42)

# Initialize TF-IDF Vectorizer with bigrams, minimum document frequency of 3, and max document frequency of 90%
vectorizer = TfidfVectorizer(ngram_range=(1, 2), min_df=3, max_df=0.9, sublinear_tf=True)

# Fit the vectorizer on training data and transform it into numerical feature vectors
X_train_vectorized = vectorizer.fit_transform(X_train)

# Transform the test data using the fitted vectorizer
X_test_vectorized = vectorizer.transform(X_test)

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.metrics import confusion_matrix

# def plot_confusion_matrix(cm, classes, normalized=True, cmap='BuPu'):
#     plt.figure(figsize=[10, 8])
    
#     if normalized:
#         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize by row sum
    
#     sns.heatmap(cm, annot=True, fmt='.2f' if normalized else 'g', 
#                 xticklabels=classes, yticklabels=classes, cmap=cmap)
    
#     plt.xlabel('Predicted Label')
#     plt.ylabel('True Label')
#     plt.title('Confusion Matrix')
#     plt.show()

# # Compute confusion matrix
# cm = confusion_matrix(y_test, preds)

# # Call the function with correct labels
# plot_confusion_matrix(cm, ['negative', 'neutral', 'positive'])

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_vectorized, y_train)

# %%
from sklearn.metrics import classification_report

# from sklearn.naive_bayes import MultinomialNB
# nb = MultinomialNB()
# nb.fit(X_train_vectorized, y_train)
# preds = nb.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier(n_estimators=100, random_state=42)
# rf.fit(X_train_vectorized, y_train)
# preds = rf.predict(X_test_vectorized)
# print(classification_report(y_test, preds))

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_smote, y_train_smote)
preds = rf.predict(X_test_vectorized)
print(classification_report(y_test, preds))

# from sklearn.linear_model import LogisticRegression
# lr = LogisticRegression(solver='liblinear')
# lr.fit(X_train_vectorized, y_train)
# preds = lr.predict(X_test_vectorized)
# print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.97      0.99      0.98     16663
#      neutral       1.00      0.98      0.99     12743
#     positive       0.98      0.98      0.98     16566
#
#     accuracy                           0.98     45972
#    macro avg       0.99      0.98      0.98     45972
# weighted avg       0.98      0.98      0.98     45972

# %%
def predict_sentiment(review):
    processed_review = preprocess_text(review)
    vectorized_review = vectorizer.transform([processed_review])
    sentiment = rf.predict(vectorized_review)[0]
    return sentiment

# %%
new_review = """

I hate it


"""
print("Predicted sentiment:", predict_sentiment(new_review))
# Out:
# Predicted sentiment: positive
